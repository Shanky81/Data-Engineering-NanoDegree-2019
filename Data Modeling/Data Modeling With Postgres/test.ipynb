# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 9;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 9 rows affected.
# [(1, datetime.datetime(2018, 11, 12, 2, 37, 38, 796000), '10', 'free', None, None, 345, 'Washington-Arlington-Alexandria, DC-VA-MD-WV', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"'),
#  (2, datetime.datetime(2018, 11, 12, 2, 37, 44, 796000), '53', 'free', None, None, 438, 'Klamath Falls, OR', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"'),
#  (3, datetime.datetime(2018, 11, 12, 2, 42, 21, 796000), '53', 'free', None, None, 438, 'Klamath Falls, OR', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"'),
# ...

# %%
# %sql SELECT * FROM users LIMIT 9;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 9 rows affected.
# [('10', 'Sylvie', 'Cruz', 'F', 'free'),
#  ('53', 'Celeste', 'Williams', 'F', 'free'),
#  ('29', 'Jacqueline', 'Lynch', 'F', 'paid'),
#  ('68', 'Jordan', 'Rodriguez', 'F', 'free'),
#  ('94', 'Noah', 'Chavez', 'M', 'free'),
#  ('100', 'Adler', 'Barrera', 'M', 'free'),
#  ('58', 'Emily', 'Benson', 'F', 'paid'),
#  ('34', 'Evelin', 'Ayala', 'F', 'free'),
#  ('49', 'Chloe', 'Cuevas', 'F', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 9;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 9 rows affected.
# [('SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 'ARMAC4T1187FB3FA4C', 2004, 207.77751),
#  ('SOGNCJP12A58A80271', 'Do You Finally Need A Friend', 'ARB29H41187B98F0EF', 1972, 342.56934),
#  ('SOPSWQW12A6D4F8781', 'Made Like This (Live)', 'ARGIWFO1187B9B55B7', 0, 225.09669),
#  ('SOVYKGO12AB0187199', 'Crazy Mixed Up World', 'ARH4Z031187B9A71F2', 1961, 156.39465),
#  ('SOZCTXZ12AB0182364', 'Setanta matins', 'AR5KOSW1187FB35FF4', 0, 269.58322),
#  ('SOGXHEG12AB018653E', 'It Makes No Difference Now', 'AR0RCMP1187FB3F427', 1992, 133.32853),
#  ('SOYTPEP12AB0180E7B', 'Twist and Shout', 'ARAJPHH1187FB5566A', 1964, 164.80608),
#  ('SOBLGCN12AB0183212', 'James (Hold The Ladder Steady)', 'AR47JEX1187B995D81', 1985, 124.86485),
#  ('SOBZBAZ12A6D4F8742', 'Spanish Grease', 'AROUOZZ1187B9ABE51', 1997, 168.25424)]

# %%
# %sql SELECT * FROM artists LIMIT 9;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 9 rows affected.
# [('ARMAC4T1187FB3FA4C', 'The Dillinger Escape Plan', 'Morris Plains, NJ', 40.82624, -74.47995),
#  ('ARB29H41187B98F0EF', 'Terry Callier', 'Chicago', 41.88415, -87.63241),
#  ('ARGIWFO1187B9B55B7', 'Five Bolt Main', '', None, None),
#  ('ARH4Z031187B9A71F2', 'Faye Adams', 'Newark, NJ', 40.73197, -74.17418),
#  ('AR5KOSW1187FB35FF4', 'Elena', 'Dubai UAE', 49.80388, 15.47491),
#  ('AR0RCMP1187FB3F427', 'Billie Jo Spears', 'Beaumont, TX', 30.08615, -94.10158),
#  ('ARAJPHH1187FB5566A', 'The Shangri-Las', 'Queens, NY', 40.7038, -73.83168),
#  ('AR47JEX1187B995D81', 'SUE THOMPSON', 'Nevada, MO', 37.83721, -94.35868),
#  ('AROUOZZ1187B9ABE51', 'Willie Bobo', 'New York, NY [Spanish Harlem]', 40.79195, -73.94512)]

# %%
# %sql SELECT * FROM time LIMIT 9;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 9 rows affected.
# [(datetime.datetime(2018, 11, 12, 2, 37, 38, 796000), 2, 12, 46, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 12, 2, 37, 44, 796000), 2, 12, 46, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 12, 2, 42, 21, 796000), 2, 12, 46, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 12, 2, 45, 52, 796000), 2, 12, 46, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 12, 2, 47, 22, 796000), 2, 12, 46, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 12, 2, 50, 21, 796000), 2, 12, 46, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 12, 2, 54, 26, 796000), 2, 12, 46, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 12, 2, 57, 12, 796000), 2, 12, 46, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 12, 3, 0, 48, 796000), 3, 12, 46, 11, 2018, 0)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql  Select location, session_id, Count(*) as Total_Records from songplays group by location, session_id order by Total_Records desc  LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [('Atlanta-Sandy Springs-Roswell, GA', 589, 117),
#  ('Lake Havasu City-Kingman, AZ', 984, 111),
#  ('San Jose-Sunnyvale-Santa Clara, CA', 324, 108),
#  ('Lake Havasu City-Kingman, AZ', 672, 106),
#  ('Chicago-Naperville-Elgin, IL-IN-WI', 221, 101),
#  ('Lansing-East Lansing, MI', 293, 99),
#  ('San Francisco-Oakland-Hayward, CA', 1041, 92),
#  ('Lansing-East Lansing, MI', 605, 85),
#  ('Waterloo-Cedar Falls, IA', 619, 81),
#  ('Winston-Salem, NC', 411, 80)]
